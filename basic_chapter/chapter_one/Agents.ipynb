# %% [markdown]
# Basic Code

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.messages import HumanMessage,SystemMessage,AIMessage
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser,JsonOutputParser
from langchain_core.runnables import RunnableParallel
from langchain_core.output_parsers import format_instructions
from langchain_community.tools import DuckDuckGoSearchRun
from langchain_community.tools import WikipediaQueryRun
from langchain_community.utilities import WikipediaAPIWrapper
from langgraph.prebuilt import create_react_agent
# from langchain.agents import  AgentExecutor
from pydantic import BaseModel,Field
from langchain.tools import tool
from dotenv import load_dotenv
import os

# %% [markdown]
# Envrinoment Varibable Checking

# %% [markdown]
# API Key Validation

# %%
from google.genai.errors import APIError
llm_gemini=ChatGoogleGenerativeAI(model="gemini-3.5-flash-lite")
try:
    response = llm_gemini.invoke("Hello")
    print(response.content)
except Exception as e:
    print("Raw Error:", e)
# Out:
# Direct use of automatic function calling (AFC) in Models.generate_content is not recommended. Instead, we recommend to use AFC in Chat.send_message. Similarly, direct use of AFC in Models.generate_content_stream is not recommended. Instead, we recommend to use AFC in Chat.send_message_stream.
# [{'type': 'text', 'text': 'Hello! How can I help you today?', 'extras': {'signature': 'El4KXAERTTIPqYglfmgzldeQbPOPnEwVc00kpzK9XtsWxi/syz576+JDW3go6heaC8qqsGV6wFUUuYH054PUBwPWaWFsZsNC617ycFCX9oiVtgQw16uoWwxAA5bEp2/Z'}}]

# %% [markdown]
# Custom Tools

# %%
import os
from dotenv import load_dotenv
from langchain_core.tools import tool
from langchain_google_genai import ChatGoogleGenerativeAI
from langgraph.prebuilt import create_react_agent

load_dotenv()

# 1. Initialize the LLM
llm_gemini=ChatGoogleGenerativeAI(model="gemini-3.5-flash-lite")


# 2. Define tools with correct return values
@tool
def add(a: int, b: int) -> int:
    """Add two numbers."""
    return a + b


@tool
def subtract(a: int, b: int) -> int:
    """Subtract two numbers."""
    return a - b


@tool
def multiply(a: int, b: int) -> int:
    """Multiply two numbers."""
    return a * b


@tool
def divide(a: int, b: int) -> float:
    """Divide two numbers."""
    if b == 0:
        return "Error: Cannot divide by zero."
    return a / b


math_tools = [add, subtract, multiply, divide]

# 3. Create the LangGraph agent
agent = create_react_agent(llm_gemini, math_tools)

# 4. Invoke the agent directly with messages input
result = agent.invoke({"messages": [("user", "calculate addition of 4 and 2")]})

# 5. Extract and print the final assistant message
print(result["messages"][-1].content)
# Out:
# C:\Users\Komalkumar M A\AppData\Local\Temp\ipykernel_30624\2251519961.py:43: LangGraphDeprecatedSinceV10: create_react_agent has been moved to `langchain.agents`. Please update your import to `from langchain.agents import create_agent`. Deprecated in LangGraph V1.0 to be removed in V2.0.
#   agent = create_react_agent(llm_gemini, math_tools)
# [{'type': 'text', 'text': 'The sum of 4 and 2 is 6.', 'extras': {'signature': 'El4KXAERTTIPNlnNd3eMzA1NasNL9++OlfPSc6Km4cnyLvIx4efkcMT8fCXXJpQ42aGrmD778s9mlNiK4iowIZlGAPk7hSEdqMdOwcO5QEeF+jjvAqrDSslN2x9MndjZ'}}]

# %% [markdown]
# Agent Reasoning Process

# %%
# Out:
# C:\Users\Komalkumar M A\AppData\Local\Temp\ipykernel_30624\3688867519.py:44: LangGraphDeprecatedSinceV10: create_react_agent has been moved to `langchain.agents`. Please update your import to `from langchain.agents import create_agent`. Deprecated in LangGraph V1.0 to be removed in V2.0.
#   agent = create_react_agent(llm_gemini, math_tools,Verbose=True)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 44
#      40
#      41 math_tools = [add, subtract, multiply, divide]
#      42
#      43 # 3. Create the LangGraph agent
# ---> 44 agent = create_react_agent(llm_gemini, math_tools,Verbose=True)
#      45
#      46 # 4. Invoke the agent directly with messages input
#      47 result = agent.invoke({"messages": [("user", "calculate addition of 4 and 2")]})
#
# File ~\OneDrive\Desktop\LangChain\.venv\Lib\site-packages\typing_extensions.py:3140, in deprecated.__call__.<locals>.wrapper(*args, **kwargs)
#    3137 @functools.wraps(arg)
#    3138 def wrapper(*args, **kwargs):
#    3139     warnings.warn(msg, category=category, stacklevel=stacklevel + 1)
# -> 3140     return arg(*args, **kwargs)
#
# File ~\OneDrive\Desktop\LangChain\.venv\Lib\site-packages\langgraph\prebuilt\chat_agent_executor.py:529, in create_react_agent(model, tools, prompt, response_format, pre_model_hook, post_model_hook, state_schema, context_schema, checkpointer, store, interrupt_before, interrupt_after, debug, version, name, **deprecated_kwargs)
#     526         context_schema = config_schema
#     528 if len(deprecated_kwargs) > 0:
# --> 529     raise TypeError(
#     530         f"create_react_agent() got unexpected keyword arguments: {deprecated_kwargs}"
#     531     )
#     533 if version not in ("v1", "v2"):
#     534     raise ValueError(
#     535         f"Invalid version {version}. Supported versions are 'v1' and 'v2'."
#     536     )
#
# TypeError: create_react_agent() got unexpected keyword arguments: {'Verbose': True}
