# %%
print("hello this world")

# %%
from dotenv import load_dotenv
if os.environ.get("GOOGLE_API_KEY"):
    print("api key is found that is gemini")
else:
    raise ValueError("GOOGLE_API_KEY environment variable not set")

# %%
from google.ai.generativelanguage_v1beta.types import content
import os
from langchain_google_genai import ChatGoogleGenerativeAI
model = ChatGoogleGenerativeAI(model="gemini-3.5-flash")
model.invoke("tell me about criicket").content
# Out:
# '**Cricket** is the second most popular sport in the world (behind soccer), with an estimated 2.5 billion fans globally. It is a bat-and-ball game played between two teams of 11 players each. \n\nWhile it can seem complex to beginners, the basic concept is quite simple. Here is a complete guide to understanding cricket.\n\n---\n\n### 1. The Core Objective\nThe game is played on a large oval grass field. In the center is a 22-yard (20-meter) strip called the **pitch**. \n\n* **The Batting Team** tries to score as many **runs** (points) as possible.\n* **The Fielding/Bowling Team** tries to limit those runs and get the batters **"out"** (dismissed).\n* Once the batting team is all out (or their limited number of throws is completed), the teams swap roles. The team with the most runs at the end wins.\n\n---\n\n### 2. The Setup: The Pitch and Wickets\nAt each end of the 22-yard pitch, there is a **wicket**—a structure made of three wooden stakes (**stumps**) pushed into the ground, with two small wooden blocks (**bails**) resting on top. \n\n* **The Bowler** (similar to a pitcher in baseball) stands at one end of the pitch and bowls the ball toward the wicket at the other end.\n* **The Batter** stands in front of the wicket to defend it with a flat wooden bat and to hit the ball to score runs.\n\n---\n\n### 3. How to Score Runs\nThere are two main ways to score runs:\n\n1. **Running:** If the batter hits the ball into the field, the two batters (one at each end of the pitch) run to the opposite ends. Every time they successfully swap ends, it counts as **1 run**. They can run back and forth multiple times if the ball is hit far away.\n2. **Boundaries (Automatic Runs):**\n   * **4 Runs:** If the batter hits the ball and it bounces or rolls past the boundary line at the edge of the field.\n   * **6 Runs:** If the batter hits the ball directly over the boundary line without it touching the ground (the cricket equivalent of a home run).\n\n---\n\n### 4. How to Get a Batter Out (Dismissals)\nThe fielding team wants to get 10 of the 11 batters out. Once 10 batters are out, the innings ends. The most common ways to get out are:\n\n* **Bowled:** The bowler bowls the ball, the batter misses, and the ball hits the wicket, knocking the bails off.\n* **Caught:** The batter hits the ball, and a fielder catches it before it touches the ground.\n* **Leg Before Wicket (LBW):** The ball hits the batter\'s leg instead of the bat. If the referee (umpire) decides the ball would have hit the wicket if the leg wasn\'t in the way, the batter is out.\n* **Run Out:** While the batters are running between the wickets, a fielder throws the ball and hits the wicket before the running batter reaches the safe line (called the **crease**).\n* **Stumped:** The batter steps forward out of their safe zone to hit the ball, misses, and the wicketkeeper (the fielder behind the wickets) catches the ball and knocks the bails off.\n\n---\n\n### 5. Key Terms to Know\n* **Over:** A bowler bowls **6 legal balls** in a row. This is called an "over." After 6 balls, a different bowler must bowl from the opposite end.\n* **Wicketkeeper:** The fielder who wears gloves and stands directly behind the batter\'s wicket (like a catcher in baseball).\n* **Innings:** The period of time a team spends batting.\n\n---\n\n### 6. The Three Formats of Cricket\nModern cricket is played in three main formats, ranging from traditional to ultra-fast:\n\n1. **Test Cricket (The Traditional Format):**\n   * **Duration:** Up to 5 days.\n   * **Style:** Players wear white clothes and use a red ball. There is no limit on how many overs can be bowled. It is a slow, strategic game of endurance.\n2. **One Day Internationals (ODIs):**\n   * **Duration:** About 8 hours (1 day).\n   * **Style:** Each team gets **50 overs** (300 balls) to bat. Players wear colored kits and use a white ball.\n3. **Twenty20 (T20):**\n   * **Duration:** About 3 hours.\n   * **Style:** The most popular and explosive format. Eac ...
